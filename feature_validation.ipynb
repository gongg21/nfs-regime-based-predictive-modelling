# %%
import sys, subprocess

try:
    import nbformat  # noqa
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "nbformat>=4.2.0"])
    import nbformat  # noqa

import pandas as pd
import numpy as np
from pathlib import Path
import plotly.graph_objects as go
import plotly.io as pio
from statsmodels.stats.outliers_influence import variance_inflation_factor

pio.renderers.default = "notebook_connected"  

# ----- Load -----
PROC_DIR = Path("../data/processed")
MERGED_PATH = PROC_DIR / "merged_macro_factors_monthly.csv"
df = pd.read_csv(MERGED_PATH, parse_dates=["Date"]).set_index("Date").sort_index()

# ----- Columns -----
factor_cols_req = ["Mkt-RF", "SMB", "HML", "RMW", "CMA", "RF"]
macro_cols_req  = ["market", "yield_curve", "oil ($/bbl)", "copper ($/metric ton)",
                   "monetary_policy", "volatility", "stock_bond_corr"]

def existing_numeric(df, cols):
    keep, miss = [], []
    for c in cols:
        if c in df.columns and pd.api.types.is_numeric_dtype(df[c]):
            keep.append(c)
        else:
            miss.append(c)
    return keep, miss

factor_cols, miss_f = existing_numeric(df, factor_cols_req)
macro_cols,  miss_m = existing_numeric(df, macro_cols_req)
factor_core = [c for c in factor_cols if c.upper() != "RF"]

XF = df[factor_core].dropna().copy() if factor_core else pd.DataFrame(index=df.index)
XM = df[macro_cols].dropna().copy()   if macro_cols else pd.DataFrame(index=df.index)
XC = df[factor_core + macro_cols].dropna().copy() if (factor_core and macro_cols) else XF.copy()

print("[INFO] Factors:", factor_core)
print("[INFO] Macros :", macro_cols)
if miss_f: print("[WARN] Missing/non-numeric (factors):", miss_f)
if miss_m: print("[WARN] Missing/non-numeric (macros):",  miss_m)

# ----- Correlations -----
def safe_corr(df_, method="pearson"):
    return df_.corr(method=method) if df_.shape[1] > 0 else pd.DataFrame()

corrF = safe_corr(XF, "pearson")
corrM = safe_corr(XM, "pearson")

def cross_corr(A: pd.DataFrame, B: pd.DataFrame):
    if A.empty or B.empty: return pd.DataFrame()
    out = pd.DataFrame(index=A.columns, columns=B.columns, dtype=float)
    for a in A.columns:
        for b in B.columns:
            out.loc[a, b] = A[a].corr(B[b])
    return out
crossFM = cross_corr(XF, XM)

# ----- VIF & Condition number -----
def compute_vif_table(X: pd.DataFrame) -> pd.DataFrame:
    if X.empty or X.shape[1] < 2:
        return pd.DataFrame(columns=["variable","VIF","Tolerance"])
    Xs = (X - X.mean()) / X.std(ddof=0)
    Xs = Xs.loc[:, Xs.std() > 0].copy()
    if Xs.shape[1] == 0:
        return pd.DataFrame(columns=["variable","VIF","Tolerance"])
    vifs = [variance_inflation_factor(Xs.values, i) for i in range(Xs.shape[1])]
    tbl = pd.DataFrame({"variable": Xs.columns, "VIF": vifs})
    tbl["Tolerance"] = 1.0 / tbl["VIF"]
    return tbl.sort_values("VIF", ascending=False).reset_index(drop=True)

def condition_number(X: pd.DataFrame) -> float:
    if X.empty or X.shape[1] < 2: return np.nan
    Xs = (X - X.mean()) / X.std(ddof=0)
    Xs = Xs.loc[:, Xs.std() > 0].copy()
    if Xs.shape[1] < 2: return np.nan
    u, s, vh = np.linalg.svd(Xs.dropna().values, full_matrices=False)
    return np.inf if (s.min() == 0) else float(s.max()/s.min())

vif_F = compute_vif_table(XF)
vif_C = compute_vif_table(XC)
cn_F  = condition_number(XF)
cn_C  = condition_number(XC)

# ----- Plot helpers (ONLY show()) -----
def heatmap_annot(z_df: pd.DataFrame, title: str):
    if z_df.empty:
        print(f"[SKIP] Heatmap {title} (empty)")
        return
    z = z_df.values
    x = list(z_df.columns)
    y = list(z_df.index)
    text = [[f"{val:.2f}" if pd.notna(val) else "" for val in row] for row in z]
    fig = go.Figure(data=go.Heatmap(
        z=z, x=x, y=y,
        colorscale="RdBu", reversescale=True, zmid=0,
        colorbar=dict(title="ρ"),
        text=text, texttemplate="%{text}",
        hovertemplate="x=%{x}<br>y=%{y}<br>ρ=%{z:.3f}<extra></extra>"
    ))
    fig.update_layout(
        title=title,
        xaxis=dict(tickangle=45),
        width=max(700, 70*len(x)+220),
        height=max(520, 32*len(y)+220),
        margin=dict(l=90,r=20,t=60,b=90)
    )
    fig.show()

def table_vif(tbl: pd.DataFrame, title: str):
    if tbl.empty:
        print(f"[SKIP] {title} (empty)")
        return
    fig = go.Figure(data=[go.Table(
        header=dict(values=["Variable","VIF","Tolerance"], align="left"),
        cells=dict(values=[tbl["variable"], tbl["VIF"].round(3), tbl["Tolerance"].round(3)],
                   align="left")
    )])
    fig.update_layout(title=title, width=720, height=420)
    fig.show()

def splom_factors(X: pd.DataFrame, title: str):
    if X.shape[1] < 2:
        print("[SKIP] SPLOM (need ≥2 factor columns)")
        return
    n = X.shape[1]
    size = max(700, 180*n)
    dimensions=[dict(label=c, values=X[c]) for c in X.columns]
    fig = go.Figure(data=go.Splom(
        dimensions=dimensions, showupperhalf=False, diagonal_visible=True,
        marker=dict(size=4, opacity=0.65)
    ))
    fig.update_layout(title=title, dragmode="select", width=size, height=size)
    fig.show()

def scatter_with_reg(x, y, xname, yname, title):
    xv = np.asarray(x, dtype=float)
    yv = np.asarray(y, dtype=float)
    mask = np.isfinite(xv) & np.isfinite(yv)
    if mask.sum() < 3:
        print(f"[SKIP] {title} (too few points)")
        return
    b, a = np.polyfit(xv[mask], yv[mask], 1)  # slope, intercept
    yhat = a + b*xv[mask]
    ss_res = ((yv[mask]-yhat)**2).sum()
    ss_tot = ((yv[mask]-yv[mask].mean())**2).sum()
    r2 = 1 - ss_res/ss_tot if ss_tot>0 else np.nan
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=xv[mask], y=yv[mask], mode="markers", name="Data",
        hovertemplate=f"{xname}=%{{x:.4f}}<br>{yname}=%{{y:.4f}}<extra></extra>",
    ))
    xs = np.linspace(xv[mask].min(), xv[mask].max(), 100)
    fig.add_trace(go.Scatter(
        x=xs, y=a + b*xs, mode="lines",
        name=f"OLS fit (β={b:.3f}, R²={r2:.3f})", hoverinfo="skip"
    ))
    fig.update_layout(
        title=title, xaxis_title=xname, yaxis_title=yname,
        width=680, height=500,
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
    )
    fig.show()

# ----- Draw (inline only) -----
heatmap_annot(corrF, "Pearson Correlation — Factors")
if not corrM.empty:
    heatmap_annot(corrM, "Pearson Correlation — Macros")
if not crossFM.empty:
    heatmap_annot(crossFM, "Pearson Cross-Correlation — Factors × Macros")

splom_factors(XF, "Scatterplot Matrix — Factor Returns")

table_vif(vif_F, "VIF — Factors only")
table_vif(vif_C, "VIF — Combined (Factors + Macros)")

# Factor vs Macro (aligned dates)
max_macros_to_plot = min(6, len(macro_cols))  
for m in macro_cols[:max_macros_to_plot]:
    for f in XF.columns:
        pair = pd.concat([XF[f].rename(f), XM[m].rename(m)], axis=1, join="inner").dropna()
        if len(pair) < 3:
            print(f"[SKIP] {m} vs {f} (too few aligned points)")
            continue
        scatter_with_reg(
            x=pair[f], y=pair[m],
            xname=f, yname=m,
            title=f"{m} vs {f} — with OLS line"
        )
# Out:
# [INFO] Factors: ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
# [INFO] Macros : ['market', 'yield_curve', 'oil ($/bbl)', 'copper ($/metric ton)', 'monetary_policy', 'volatility', 'stock_bond_corr']
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="2e300365-8ee2-48ab-87e0-70bafbc403d3" class="plotly-graph-div" style="height:520px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2e300365-8ee2-48ab-87e0-70bafbc403d3")) {                    Plotly.newPlot(                        "2e300365-8ee2-48ab-87e0-70bafbc403d3",                        [{"colorbar":{"title":{"text":"\u03c1"}},"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003e\u03c1=%{z:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","reversescale":true,"text":[["1.00","0.25","-0.22","-0.07","-0.30"],["0.25","1.00","0.04","-0.19","-0.00"],["-0.22","0.04","1.00","0.06","0.75"],["-0.07","-0.19","0.06","1.00","-0.10"],["-0.30","-0.00","0.75","-0.10","1.00"]],"texttemplate":"%{text}","x":["Mkt-RF","SMB","HML","RMW","CMA"],"y":["Mkt-RF","SMB","HML","RMW","CMA"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D8pqVyOvkDQPyS0TkGpmMy\u002f5lodmv3Gsr\u002fIqgKsDgfTvympXI6+QNA\u002fAAAAAAAA8D\u002f5dZ8moQClP5Jt3tTJZMi\u002fEEKgGk2jc78ktE5BqZjMv\u002fl1nyahAKU\u002fAAAAAAAA8D\u002fWc3ilCWOwP63995m78+c\u002f5lodmv3Gsr+Sbd7UyWTIv9ZzeKUJY7A\u002fAAAAAAAA8D8Y705QpJG6v8iqAqwOB9O\u002fEEKgGk2jc7+t\u002ffeZu\u002fPnPxjvTlCkkbq\u002fAAAAAAAA8D8=","shape":"5, 5"},"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10," ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="6f6505fa-72ed-4fd8-8b0b-3510727b159e" class="plotly-graph-div" style="height:520px; width:710px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f6505fa-72ed-4fd8-8b0b-3510727b159e")) {                    Plotly.newPlot(                        "6f6505fa-72ed-4fd8-8b0b-3510727b159e",                        [{"colorbar":{"title":{"text":"\u03c1"}},"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003e\u03c1=%{z:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","reversescale":true,"text":[["1.00","0.44","0.66","0.82","-0.45","0.51","0.12"],["0.44","1.00","0.47","0.52","-1.00","0.59","0.56"],["0.66","0.47","1.00","0.90","-0.48","0.51","0.34"],["0.82","0.52","0.90","1.00","-0.54","0.50","0.29"],["-0.45","-1.00","-0.48","-0.54","1.00","-0.59","-0.56"],["0.51","0.59","0.51","0.50","-0.59","1.00","0.35"],["0.12","0.56","0.34","0.29","-0.56","0.35","1.00"]],"texttemplate":"%{text}","x":["market","yield_curve","oil ($\u002fbbl)","copper ($\u002fmetric ton)","monetary_policy","volatility","stock_bond_corr"],"y":["market","yield_curve","oil ($\u002fbbl)","copper ($\u002fmetric ton)","monetary_policy","volatility","stock_bond_corr"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D+MDNV78N\u002fbP2ju98t5CeU\u002fo7VfwbYi6j+Edy7\u002fXAbdvxPMY7iJROA\u002ftyPmFpmXvz+MDNV78N\u002fbPwAAAAAAAPA\u002fc\u002fZmmDUj3j\u002fCWPOqkr3gP5pFPWYe+e+\u002fhn7ip2Lj4j9Lwy9vUuLhP2ju98t5CeU\u002fc\u002fZmmDUj3j8AAAAAAADwPzUQW9qW7ew\u002fCFqJQNt83r\u002ffHe2\u002fWj\u002fgP7Y0O8qO7dU\u002fo7VfwbYi6j\u002fCWPOqkr3gPzUQW9qW7ew\u002fAAAAAAAA8D+Ac0Ysbynhv63DF+CbD+A\u002fkGzQ8+xt0j+Edy7\u002fXAbdv5pFPWYe+e+\u002fCFqJQNt83r+Ac0YsbynhvwAAAAAAAPA\u002fAUHeffwC478CnSJdYwLivxPMY7iJROA\u002fhn7ip2Lj4j\u002ffHe2\u002fWj\u002fgP63DF+CbD+A\u002fAUHeffwC478AAAAAAADwP+HXoy1ugtY\u002ftyPmFpmXvz9Lwy9vUuLhP7Y0O8qO7dU\u002fkGzQ8+xt0j8CnSJdYwLiv+HXoy1ugtY\u002fAAAAAAAA8D8=","shape":"7, 7"},"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="1994d9ea-32b4-44e4-9613-26d035dbebb9" class="plotly-graph-div" style="height:520px; width:710px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1994d9ea-32b4-44e4-9613-26d035dbebb9")) {                    Plotly.newPlot(                        "1994d9ea-32b4-44e4-9613-26d035dbebb9",                        [{"colorbar":{"title":{"text":"\u03c1"}},"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003e\u03c1=%{z:.3f}\u003cextra\u003e\u003c\u002fextra\u003e","reversescale":true,"text":[["0.06","0.07","0.03","0.04","-0.06","-0.05","-0.04"],["-0.08","0.03","-0.05","-0.08","-0.02","-0.04","0.03"],["-0.04","-0.03","-0.05","-0.06","0.04","-0.04","-0.03"],["0.05","-0.01","0.05","0.05","0.01","0.08","-0.07"],["-0.06","-0.05","-0.05","-0.06","0.05","0.01","0.02"]],"texttemplate":"%{text}","x":["market","yield_curve","oil ($\u002fbbl)","copper ($\u002fmetric ton)","monetary_policy","volatility","stock_bond_corr"],"y":["Mkt-RF","SMB","HML","RMW","CMA"],"z":{"dtype":"f8","bdata":"eyBsmGn2rD8PoBfOi8KwP9O3lzVsFZ8\u002fCUrOaLWlpD\u002fGaCenJaCwv5lCnDCWGau\u002fGacL9Bcbpr+cSNA+1tizvypfpH7f55o\u002f3pNHO0zpqb+1JoF2SnW1v\u002feUJoODHpi\u002f1S9Gwt\u002fEpL\u002fxYv1UExqgPz7TNhennKK\u002fu+EvwFnUoL+TsND9sS+nv8dWQOrsuK2\u002fpdhWNLLhoj+rv6qW1YSmv9ZHWBNZTaG\u002fgfPYWHpRqj+pkrNJcsF+v+ydpB6Y3qg\u002fbEczYKzyqj9iwOPMvxR+P\u002f1j7SLRPbM\u002f7gx0u+eKsr\u002fplpnHR0+uv4OITbzcV6e\u002fefMlLwPjqb8aZEG5swuwvzaOVd7v1ag\u002fd+SfJc2gfj\u002fpj7217Z2YPw==","shape":"5, 7"},"zmid":0,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="3e7625f6-d30c-46fc-a102-8d05d5f4bc4a" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3e7625f6-d30c-46fc-a102-8d05d5f4bc4a")) {                    Plotly.newPlot(                        "3e7625f6-d30c-46fc-a102-8d05d5f4bc4a",                        [{"diagonal":{"visible":true},"dimensions":[{"label":"Mkt-RF","values":{"dtype":"f8","bdata":"9ihcj8L12L9SuB6F61EUQB+F61G4Hvm\u002fUrgehetRBECF61G4HoXrv0jhehSuR\u002f0\u002fKVyPwvUoAkDNzMzMzMz4P4\u002fC9Shcj\u002fY\u002fKVyPwvUovD+PwvUoXI\u002f2P1K4HoXrUfQ\u002f16NwPQrX+z8K16NwPQr3v4XrUbgehQVAMzMzMzMz4z97FK5H4XqEv3sUrkfheqQ\u002fUrgehetRDEApXI\u002fC9SjcP3E9CtejcPW\u002f4XoUrkfhCED2KFyPwvXovwrXo3A9ChbACtejcD0K9z\u002fXo3A9CtcFQOF6FK5H4QZAzczMzMzMBEB7FK5H4XqUvylcj8L1KPA\u002fCtejcD0K5z9cj8L1KFzzvxSuR+F6FATACtejcD0KAUCuR+F6FK4WwArXo3A9Cve\u002fFK5H4XoU+r\u002fD9Shcj8IfwPYoXI\u002fC9fC\u002f4XoUrkfhDkAUrkfhehT2P6RwPQrXo8A\u002fw\u002fUoXI+COECkcD0K16PoPwAAAAAAABBAH4XrUbgeD0BI4XoUrkcRwFyPwvUoXANAUrgehetREkDNzMzMzMzsv+F6FK5H4QhApHA9CtejCMCuR+F6FK7XP2ZmZmZmZghAUrgehevRIUDsUbgehesNwOF6FK5H4co\u002fhetRuB4FIkA9CtejcD0CQGZmZmZmZuY\u002fhetRuB6FBcCamZmZmZn1PzMzMzMzMxBAKVyPwvUo3D+uR+F6FK4VQHE9CtejcA\u002fASOF6FK6HMcBxPQrXo3AXwFyPwvUoXAVAhetRuB6F9z+amZmZmZm5v7gehetRuBzAAAAAAAAAHMDD9Shcj8ISQMP1KFyPwgfAMzMzMzMzFEBmZmZmZmYOwArXo3A9CgXAzczMzMzMGcCPwvUoXI8UQPYoXI\u002fC9fC\u002fexSuR+H6JcCkcD0K16MbwDMzMzMzMxfArkfhehSuG0AAAAAAAAASQLgehetRuBBAPQrXo3A9AsB7FK5H4XoSQPYoXI\u002fC9RZAj8L1KFyPJ0CPwvUoXI\u002f2P3sUrkfhehBAMzMzMzMzCUAAAAAAAAAQwArXo3A9Cre\u002f9ihcj8L1EcBSuB6F61EOQIXrUbgeheu\u002frkfhehSuEcBxPQrXo3Ddv+xRuB6FayFAw\u002fUoXI\u002fCA0D2KFyPwvUGQNejcD0K1+M\u002fj8L1KFyP0j+kcD0K16P0P65H4XoUrgPAmpmZmZmZ6b8pXI\u002fC9SgKQD0K16NwPfK\u002fpHA9Ctej4D9cj8L1KFwSQNejcD0K1+M\u002fAAAAAABAOsBmZmZmZmYTwM3MzMzMzPS\u002fuB6F61G4FsDD9Shcj8IHwB+F61G4Hvm\u002fKVyPwvUoFECPwvUoXI8OwPYoXI\u002fC9RJAj8L1KFyP6r8UrkfhepQpwOF6FK5H4eI\u002fSOF6FK7nQcBxPQrXo3Ddv4\u002fC9ShcjwbAH4XrUbgeFcDNzMzMzMwSwLgehetRuAbAH4XrUbgeIMBI4XoUrsciwI\u002fC9ShcjyfAmpmZmZkZMEAfhetRuB4SwJqZmZmZmQvA16NwPQpXK0A9CtejcD0WQEjhehSuRwVA4XoUrkfhEEDNzMzMzMwUQHsUrkfhehNAZmZmZmZmGsC4HoXrUbgGwArXo3A9ChHASOF6FK5HFUAzMzMzMzMFQJqZmZmZmfm\u002fUrgehetRKEB7FK5H4XrUP4\u002fC9ShcjwJArkfhehSu97+amZmZmZn1vzMzMzMzMxBA9ihcj8L18L89CtejcD3iv1K4HoXrUQBAXI\u002fC9ShcA8CuR+F6FK7XP5qZmZmZmRZAcT0K16NwIMAK16NwPQr\u002fv5qZmZmZmfW\u002fMzMzMzMzwz+F61G4HoX3v+F6FK5H4RJACtejcD0K+78pXI\u002fC9Sj8v0jhehSuR9G\u002fj8L1KFyPEcAUrkfhehQQQEjhehSuR9E\u002fzczMzMzM8D89CtejcD32v83MzMzMzAZAexSuR+F6H0ApXI\u002fC9Sj8PwrXo3A9Cvu\u002fexSuR+F6FEBSuB6F61EOQDMzMzMzM\u002fe\u002fUrgehevRJ8DD9Shcj8IFQClcj8L1KOw\u002frkfhehQuKkB7FK5H4XoMwK5H4XoUrhZA7FG4HoXrsb+uR+F6FK4BwLgehetRuA5Aj8L1KFyP6j8pXI\u002fC9SgWQI\u002fC9Shcj+q\u002fMzMzMzMzIMDsUbgehesUQHsUrkfhevw\\u002f7FG4HoXrCUBxPQrXo3APwKRwPQrXowjAmpmZmZmZCcDNzMzMzEwmQB+F61G4HvU\u002fexSuR+F6JkC4HoXrUbgSQOxRuB6F6+E\u002f9ihcj8J1K0C4HoXrUbgEQHsUrkfhegZAmpmZmZmZGkBSuB6F61HgP4\u002fC9ShcjwhAPQrXo3A9EMAAAAAAAADgvx+F61G4Hu0\u002fcT0K16NwC8BI4XoUrkcBQFK4HoXrUfy\u002f7FG4HoXrF8AK16NwPQoTwM3MzMzMzOQ\u002fUrgehetR4L\u002fsUbgehesXwPYoXI\u002fC9fw\u002fw\u002fUoXI\u002fCBcAK16NwPYokQJqZmZmZmem\u002f4XoUrkfh6r9SuB6F61H8v3E9CtejcP0\u002fKVyPwvXoOECF61G4HoXzP+F6FK5H4eq\u002fuB6F61G47r9I4XoUrkcUQFK4HoXrUfQ\u002fCtejcD0K578pXI\u002fC9SjwvwAAAAAAABLAAAAAAAAAEEDXo3A9CtcZQArXo3A9Cg9AzczMzMzM5D+PwvUoXI8cQKRwPQrXo ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ea7e7377-a2b4-49ed-b6c7-6a8dfc7480a1" class="plotly-graph-div" style="height:420px; width:720px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ea7e7377-a2b4-49ed-b6c7-6a8dfc7480a1")) {                    Plotly.newPlot(                        "ea7e7377-a2b4-49ed-b6c7-6a8dfc7480a1",                        [{"cells":{"align":"left","values":[["CMA","HML","Mkt-RF","SMB","RMW"],[2.53,2.415,1.184,1.121,1.114],[0.395,0.414,0.845,0.892,0.898]]},"header":{"align":"left","values":["Variable","VIF","Tolerance"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap"," ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="c5a75f15-d651-4b6a-8c2f-5e54767acc82" class="plotly-graph-div" style="height:420px; width:720px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c5a75f15-d651-4b6a-8c2f-5e54767acc82")) {                    Plotly.newPlot(                        "c5a75f15-d651-4b6a-8c2f-5e54767acc82",                        [{"cells":{"align":"left","values":[["monetary_policy","yield_curve","copper ($\u002fmetric ton)","oil ($\u002fbbl)","market","CMA","HML","volatility","stock_bond_corr","Mkt-RF","SMB","RMW"],[998.417,963.336,12.561,7.895,4.175,2.585,2.487,1.952,1.815,1.215,1.14,1.134],[0.001,0.001,0.08,0.127,0.24,0.387,0.402,0.512,0.551,0.823,0.878,0.882]]},"header":{"align":"left","values":["Variable","VIF","Tolerance"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar" ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="3c424837-aa1c-4f6d-aab1-5abbba968314" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3c424837-aa1c-4f6d-aab1-5abbba968314")) {                    Plotly.newPlot(                        "3c424837-aa1c-4f6d-aab1-5abbba968314",                        [{"hovertemplate":"Mkt-RF=%{x:.4f}\u003cbr\u003emarket=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"9ihcj8L12L9SuB6F61EUQB+F61G4Hvm\u002fUrgehetRBECF61G4HoXrv0jhehSuR\u002f0\u002fKVyPwvUoAkDNzMzMzMz4P4\u002fC9Shcj\u002fY\u002fKVyPwvUovD+PwvUoXI\u002f2P1K4HoXrUfQ\u002f16NwPQrX+z8K16NwPQr3v4XrUbgehQVAMzMzMzMz4z97FK5H4XqEv3sUrkfheqQ\u002fUrgehetRDEApXI\u002fC9SjcP3E9CtejcPW\u002f4XoUrkfhCED2KFyPwvXovwrXo3A9ChbACtejcD0K9z\u002fXo3A9CtcFQOF6FK5H4QZAzczMzMzMBEB7FK5H4XqUvylcj8L1KPA\u002fCtejcD0K5z9cj8L1KFzzvxSuR+F6FATACtejcD0KAUCuR+F6FK4WwArXo3A9Cve\u002fFK5H4XoU+r\u002fD9Shcj8IfwPYoXI\u002fC9fC\u002f4XoUrkfhDkAUrkfhehT2P6RwPQrXo8A\u002fw\u002fUoXI+COECkcD0K16PoPwAAAAAAABBAH4XrUbgeD0BI4XoUrkcRwFyPwvUoXANAUrgehetREkDNzMzMzMzsv+F6FK5H4QhApHA9CtejCMCuR+F6FK7XP2ZmZmZmZghAUrgehevRIUDsUbgehesNwOF6FK5H4co\u002fhetRuB4FIkA9CtejcD0CQGZmZmZmZuY\u002fhetRuB6FBcCamZmZmZn1PzMzMzMzMxBAKVyPwvUo3D+uR+F6FK4VQHE9CtejcA\u002fASOF6FK6HMcBxPQrXo3AXwFyPwvUoXAVAhetRuB6F9z+amZmZmZm5v7gehetRuBzAAAAAAAAAHMDD9Shcj8ISQMP1KFyPwgfAMzMzMzMzFEBmZmZmZmYOwArXo3A9CgXAzczMzMzMGcCPwvUoXI8UQPYoXI\u002fC9fC\u002fexSuR+H6JcCkcD0K16MbwDMzMzMzMxfArkfhehSuG0AAAAAAAAASQLgehetRuBBAPQrXo3A9AsB7FK5H4XoSQPYoXI\u002fC9RZAj8L1KFyPJ0CPwvUoXI\u002f2P3sUrkfhehBAMzMzMzMzCUAAAAAAAAAQwArXo3A9Cre\u002f9ihcj8L1EcBSuB6F61EOQIXrUbgeheu\u002frkfhehSuEcBxPQrXo3Ddv+xRuB6FayFAw\u002fUoXI\u002fCA0D2KFyPwvUGQNejcD0K1+M\u002fj8L1KFyP0j+kcD0K16P0P65H4XoUrgPAmpmZmZmZ6b8pXI\u002fC9SgKQD0K16NwPfK\u002fpHA9Ctej4D9cj8L1KFwSQNejcD0K1+M\u002fAAAAAABAOsBmZmZmZmYTwM3MzMzMzPS\u002fuB6F61G4FsDD9Shcj8IHwB+F61G4Hvm\u002fKVyPwvUoFECPwvUoXI8OwPYoXI\u002fC9RJAj8L1KFyP6r8UrkfhepQpwOF6FK5H4eI\u002fSOF6FK7nQcBxPQrXo3Ddv4\u002fC9ShcjwbAH4XrUbgeFcDNzMzMzMwSwLgehetRuAbAH4XrUbgeIMBI4XoUrsciwI\u002fC9ShcjyfAmpmZmZkZMEAfhetRuB4SwJqZmZmZmQvA16NwPQpXK0A9CtejcD0WQEjhehSuRwVA4XoUrkfhEEDNzMzMzMwUQHsUrkfhehNAZmZmZmZmGsC4HoXrUbgGwArXo3A9ChHASOF6FK5HFUAzMzMzMzMFQJqZmZmZmfm\u002fUrgehetRKEB7FK5H4XrUP4\u002fC9ShcjwJArkfhehSu97+amZmZmZn1vzMzMzMzMxBA9ihcj8L18L89CtejcD3iv1K4HoXrUQBAXI\u002fC9ShcA8CuR+F6FK7XP5qZmZmZmRZAcT0K16NwIMAK16NwPQr\u002fv5qZmZmZmfW\u002fMzMzMzMzwz+F61G4HoX3v+F6FK5H4RJACtejcD0K+78pXI\u002fC9Sj8v0jhehSuR9G\u002fj8L1KFyPEcAUrkfhehQQQEjhehSuR9E\u002fzczMzMzM8D89CtejcD32v83MzMzMzAZAexSuR+F6H0ApXI\u002fC9Sj8PwrXo3A9Cvu\u002fexSuR+F6FEBSuB6F61EOQDMzMzMzM\u002fe\u002fUrgehevRJ8DD9Shcj8IFQClcj8L1KOw\u002frkfhehQuKkB7FK5H4XoMwK5H4XoUrhZA7FG4HoXrsb+uR+F6FK4BwLgehetRuA5Aj8L1KFyP6j8pXI\u002fC9SgWQI\u002fC9Shcj+q\u002fMzMzMzMzIMDsUbgehesUQHsUrkfhevw\\u002f7FG4HoXrCUBxPQrXo3APwKRwPQrXowjAmpmZmZmZCcDNzMzMzEwmQB+F61G4HvU\u002fexSuR+F6JkC4HoXrUbgSQOxRuB6F6+E\u002f9ihcj8J1K0C4HoXrUbgEQHsUrkfhegZAmpmZmZmZGkBSuB6F61HgP4\u002fC9ShcjwhAPQrXo3A9EMAAAAAAAADgvx+F61G4Hu0\u002fcT0K16NwC8BI4XoUrkcBQFK4HoXrUfy\u002f7FG4HoXrF8AK16NwPQoTwM3MzMzMzOQ\u002fUrgehetR4L\u002fsUbgehesXwPYoXI\u002fC9fw\u002fw\u002fUoXI\u002fCBcAK16NwPYokQJqZmZmZmem\u002f4XoUrkfh6r9SuB6F61H8v3E9CtejcP0\u002fKVyPwvXoOECF61G4HoXzP+F6FK5H4eq\u002fuB6F61G47r9I4XoUrkcUQFK4HoXrUfQ\u002fCtejcD0K578pXI\u002fC9SjwvwAA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="6c11d009-2d14-4cd6-9b7f-d5dc427b384f" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6c11d009-2d14-4cd6-9b7f-d5dc427b384f")) {                    Plotly.newPlot(                        "6c11d009-2d14-4cd6-9b7f-d5dc427b384f",                        [{"hovertemplate":"SMB=%{x:.4f}\u003cbr\u003emarket=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"uB6F61G43r+amZmZmZnpv4XrUbgehdu\u002fcT0K16Nw9b8zMzMzMzPrvz0K16NwPf6\u002fmpmZmZmZuT8fhetRuB7VP4\u002fC9Shcj\u002fY\u002frkfhehSu97\u002fXo3A9Ctfjv6RwPQrXo8A\u002fAAAAAAAA4D+PwvUoXI\u002fSP8P1KFyPwtW\u002fzczMzMzM7D+4HoXrUbjOv83MzMzMzOS\u002fAAAAAAAABEDsUbgehesJQKRwPQrXowBAPQrXo3A98j+amZmZmZmpP83MzMzMzBDAmpmZmZmZ8T8pXI\u002fC9SgGQGZmZmZmZuY\u002fmpmZmZmZC0DhehSuR+EUQPYoXI\u002fC9QRAZmZmZmZmE0ApXI\u002fC9SgTQOF6FK5H4co\u002fpHA9CtejCkBxPQrXo3AUwB+F61G4HvU\u002fUrgehetR2L8zMzMzMzMJwFK4HoXrUfC\u002f7FG4HoXrGcC4HoXrUbgKQBSuR+F6FP4\u002f16NwPQoXSUAUrkfhehQIQFK4HoXrUfw\u002fhetRuB6F2z+amZmZmZkDQK5H4XoUrhlApHA9CtejDECkcD0K16PoP3E9CtejcANAPQrXo3A94j+4HoXrUbiuv1yPwvUoXBZAAAAAAABAOkBcj8L1KFwHwM3MzMzMzPi\u002frkfhehSuGEDhehSuR+EbQB+F61G4HtW\u002fPQrXo3A99r+kcD0K16MCQHsUrkfhegZAhetRuB6F278fhetRuB4DQGZmZmZmZgxA7FG4HoVrLMCkcD0K16MQwFK4HoXrUeC\u002f9ihcj8L16L8K16NwPQrHv+F6FK5H4RXAH4XrUbgeC8CPwvUoXI\u002fiP6RwPQrXo\u002fQ\u002fSOF6FK5HD0Bcj8L1KFwDwMP1KFyPwg3APQrXo3C9KMCPwvUoXI8EwFyPwvUoXAPAXI\u002fC9ShcGcDXo3A9CtcRwM3MzMzMzADAH4XrUbge5b8K16NwPQr3PwAAAAAAACFAcT0K16NwEcAK16NwPQoPwB+F61G4HgdAexSuR+F6FkAUrkfhehQAQMP1KFyPwgFACtejcD0K17\u002fsUbgehevxvylcj8L1KPi\u002f4XoUrkfh9r9xPQrXo3DNv6RwPQrXo9A\u002fcT0K16Nw+b\u002fhehSuR+EGwOxRuB6F6wlAXI\u002fC9ShcGEDXo3A9CtfrPxSuR+F6FN6\u002fSOF6FK5H0T\u002f2KFyPwvUIwIXrUbgehdu\u002fUrgehetRBsCuR+F6FK4LwOxRuB6F6wHAZmZmZmZmBMDhehSuR+Hivz0K16NwPf6\u002fH4XrUbgeNMCF61G4HoUPwFK4HoXrUQLAXI\u002fC9ShcB8B7FK5H4XoYwNejcD0K1wPAw\u002fUoXI\u002fCHEB7FK5H4Xr8v6RwPQrXowxASOF6FK5H0b8UrkfhehQdwOF6FK5H4RLAzczMzMzM5D+4HoXrUbi+P\u002fYoXI\u002fC9QRAH4XrUbge5b97FK5H4XoIwJqZmZmZmam\u002fcT0K16Nw\u002fT\u002fsUbgehevRP4XrUbgehfc\u002fH4XrUbgeG8CPwvUoXI\u002f2vxSuR+F6FBHAw\u002fUoXI\u002fCKUAUrkfhehTmv8P1KFyPwg9AFK5H4XoU5r\u002fXo3A9CtcHQEjhehSuR\u002fU\u002fMzMzMzMzC0ApXI\u002fC9SgGwHsUrkfhepS\u002fAAAAAAAAEcCamZmZmZnxv3sUrkfhesS\u002fj8L1KFyPGUCkcD0K16MfQBSuR+F6FPa\u002fmpmZmZmZuT9xPQrXo3Dxvx+F61G4HvG\u002fhetRuB6F4z8pXI\u002fC9SgAwJqZmZmZmck\u002fmpmZmZmZqT+amZmZmZkFQM3MzMzMzAxA7FG4HoWrOEDNzMzMzMzwP6RwPQrXo\u002fQ\u002fMzMzMzMz4z\u002fsUbgehev1P83MzMzMzABA9ihcj8L1\u002fD\u002fD9Shcj8LtP+xRuB6F6\u002fk\u002fj8L1KFyP9j\u002fNzMzMzMwMQMP1KFyPwvk\u002fw\u002fUoXI9CK0CamZmZmZkNQDMzMzMzMw1AexSuR+F61L8pXI\u002fC9SgSQD0K16NwPfo\u002fw\u002fUoXI\u002fCxT+4HoXrUbgTQFK4HoXrUdi\u002fFK5H4XoUJMAzMzMzMzMHQClcj8L1KPA\u002fuB6F61G4NED2KFyPwvXgP1yPwvUoXAlAMzMzMzMzA0AK16NwPQrHPxSuR+F6FO4\u002fUrgehetR9D+amZmZmZn9P+xRuB6F69G\u002f7FG4HoXrC8AUrkfhehQEQBSuR+F6FBFA4XoUrkfhEUDsUbgehev5v+F6FK5H4RvAzczMzMzM8D8AAAAAAAAAQFyPwvUoXPc\u002f7FG4HoXrDUDsUbgehesQQClcj8L1KOQ\u002frkfhehSuAUApXI\u002fC9SgKwOxRuB6F69G\u002fZmZmZmZmCkDNzMzMzMzkv83MzMzMzAZA4XoUrkfhEkDhehSuR+ECQMP1KFyPwu2\u002fMzMzMzMz\u002f78fhetRuB79v65H4XoUrgPAPQrXo3A9AkBI4XoUrkf5v+F6FK5H4fI\u002fMzMzMzMzHECamZmZmZnZP3sUrkfhepQ\u002fXI\u002fC9Shc8z89CtejcD3aP1K4HoXrUeC\u002fKVyPwvUo8D\u002fXo3A9CtcRwGZmZmZmZgRAXI\u002fC9Shc\u002fz+PwvUoXI8RQOxRuB6F68G\u002fcT0K16NwKEAK16NwPQoHQOxRuB6F6\u002fU\u002fhetRuB6F2z8K16NwPQoZQI\u002fC9Shcj\u002fI\u002fzczMzMzM8D9I4XoUrkcRwDMzMzMzM9M\u002fAAAAAAAADsDsUbgehev9P+F6FK5H4dq\u002fj8L1KFwPIMBI4XoUrkf5vwAAAAAAANC\u002fFK5H4XoU7r\u002fsUbgehevBP3sUrkfhesQ\u002frkfhehSuAcDsUbgehevRv3sUrkfheq ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="764940ab-8fb3-434c-b1a0-2169c9f6f2de" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("764940ab-8fb3-434c-b1a0-2169c9f6f2de")) {                    Plotly.newPlot(                        "764940ab-8fb3-434c-b1a0-2169c9f6f2de",                        [{"hovertemplate":"HML=%{x:.4f}\u003cbr\u003emarket=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"7FG4HoXr6b8zMzMzMzP7PwAAAAAAAAAAexSuR+F6pL+uR+F6FK77P+F6FK5H4cq\u002fFK5H4XoU+j97FK5H4XoGQFK4HoXrUQpASOF6FK5H4b\u002f2KFyPwvX8P8P1KFyPwuU\u002fSOF6FK5H6T\u002fsUbgeheuxP4XrUbgehfs\u002fSOF6FK5H8T9SuB6F61EAwHE9CtejcAPACtejcD0K1z8pXI\u002fC9SjMP2ZmZmZmZvI\u002fXI\u002fC9Shc5z\u002fNzMzMzMz4v3E9CtejcM0\u002fhetRuB6FAUBcj8L1KFzvv+xRuB6F68G\u002fzczMzMzM+D97FK5H4XrEPzMzMzMzMwFAKVyPwvUoCkBSuB6F61HYPwrXo3A9CgHACtejcD0K17+amZmZmZn5v1yPwvUoXN8\u002fH4XrUbge7T8AAAAAAADgP7gehetRuN4\u002f7FG4HoXrBUCF61G4HoUSwGZmZmZmZu6\u002fH4XrUbgeIMAUrkfhehQCwBSuR+F6FN4\u002fUrgehetRAsCamZmZmZnpP5qZmZmZmek\u002fAAAAAAAABkDhehSuR+H2P8P1KFyPwgPAUrgehetRCsBcj8L1KFz7v0jhehSuR+G\u002fexSuR+E6MkCuR+F6FK7zPylcj8L1KOS\u002fmpmZmZmZ8b89CtejcD3qPx+F61G4HuU\u002fPQrXo3A9FUCuR+F6FK7vPzMzMzMzM9M\u002fj8L1KFyPBkC4HoXrUbjuv3sUrkfheqQ\u002fFK5H4XoUJMB7FK5H4XrsP+F6FK5H4dq\u002fexSuR+F6lD\u002fXo3A9CtfjP5qZmZmZmfG\u002f4XoUrkfh8j8AAAAAAAAOwMP1KFyPwgnA9ihcj8L1CMAAAAAAAAD0vwrXo3A9CgfAMzMzMzNzNUCF61G4HoUNQFK4HoXrURBAj8L1KFyPGECPwvUoXI8KQClcj8L1KNw\u002fw\u002fUoXI\u002fC7T+PwvUoXI\u002f2P6RwPQrXoxXA4XoUrkfhyj9I4XoUrkf5P6RwPQrXo\u002fA\u002fXI\u002fC9SjcJcDXo3A9Ctfzv5qZmZmZmQ\u002fAhetRuB6F6z9I4XoUrkf1v4XrUbgehf+\u002fexSuR+F6lL8fhetRuB4FQDMzMzMzMwfAUrgehetR4L+4HoXrUbj6v1K4HoXrUdi\u002f9ihcj8L1AECkcD0K16MGwMP1KFyPwvm\u002fuB6F61G4nj\u002fD9Shcj8IFwK5H4XoUrgPAMzMzMzMz4z89CtejcD0SQFyPwvUoXN8\u002fhetRuB6F8z+F61G4HoUTQHE9CtejcAHAAAAAAACAMUA9CtejcD36P4\u002fC9ShcjwRAj8L1KFyPFUBSuB6F61HYPz0K16NwPfI\u002fCtejcD0KFcB7FK5H4XrwP8P1KFyPwgFAj8L1KFyP+j9cj8L1KFwQQArXo3A9ChBAzczMzMxMI0DD9Shcj8IDQOxRuB6F68G\u002fcT0K16Nw7T+kcD0K16MAwI\u002fC9Shcj+o\u002fpHA9CtejFEDhehSuR+EEQLgehetRuBVAUrgehevRI8AAAAAAAADQv7gehetRuL4\u002fhetRuB6FIEDhehSuR+ERwFyPwvUoXANAFK5H4XoU8r8zMzMzMzMQwJqZmZmZmfU\u002fKVyPwvUo\u002fD8fhetRuB7tvx+F61G4HtU\u002fZmZmZmZm1j89CtejcD0AQDMzMzMzM\u002fs\u002fw\u002fUoXI9CIUDXo3A9CtcWQClcj8L1KLy\u002fexSuR+F6xL+kcD0K16P0v1yPwvUoXOc\u002f16NwPQrX+z9I4XoUrkfpP9ejcD0K19O\u002fw\u002fUoXI\u002fCxb97FK5H4Xr4P9ejcD0K1wFAFK5H4XoUHkDNzMzMzMzcP3E9CtejcPE\u002fCtejcD0KC0DsUbgehevpP9ejcD0K1+O\u002fMzMzMzMz478pXI\u002fC9SgGwKRwPQrXo9C\u002f7FG4HoXr+T9xPQrXo3DNP4\u002fC9Shcj9K\u002fpHA9Ctej4D\u002fsUbgehevpP2ZmZmZmZvI\u002fUrgehetRDMCamZmZmZnhvzMzMzMzM+M\u002fAAAAAAAA8L8fhetRuB7lvxSuR+F6FP4\u002fKVyPwvUo9D+kcD0K16MAwB+F61G4HgHA9ihcj8L1AsC4HoXrUbjyP8P1KFyPwuW\u002f7FG4HoXr8T8fhetRuB71P7gehetRuPY\u002fpHA9Ctej\u002fD9I4XoUrkf5vxSuR+F6FO6\u002fSOF6FK5H\u002fb+uR+F6FK4JwArXo3A9CgHA4XoUrkchOMDhehSuR+HiP7gehetRuO6\u002fexSuR+F68D9SuB6F61HYP5qZmZmZmem\u002fKVyPwvUoGcCuR+F6FK4DwHE9CtejcBLAcT0K16NwB8C4HoXrUTggwGZmZmZmZgZA9ihcj8L1GkAK16NwPQrvP4XrUbgeheM\u002fPQrXo3A9AkCF61G4HoXbv4\u002fC9ShcjxRAhetRuB6F47\u002fXo3A9CtcSQHE9CtejcBRAXI\u002fC9ShcEMCPwvUoXI\u002f+P0jhehSuR+k\u002fexSuR+H6KUBcj8L1KFwYQBSuR+F6FA5ApHA9CtejCMB7FK5H4Xr8P\u002fYoXI\u002fC9fg\u002f7FG4HoXrsT9xPQrXo3DxP3E9CtejcM0\u002f9ihcj8L1DMDNzMzMzMz8v7gehetRuK6\u002f7FG4HoVrNEAfhetRuB7lP3sUrkfhegBAhetRuB6F2z9mZmZmZmb2vx+F61G4Hg\u002fAKVyPwvUoFkBcj8L1KFwWQK5H4XoUru8\u002f16NwPQrXE0Bcj8L1KFznvwAAAAAAAPw\u002fCtejcD1KM0BI4XoUrkcLQPYoXI\u002fC9eA\u002fCtejcD0K8z+kcD0K16PQPwAAAAAAAAbA9ihcj8L12D\u002fXo3A9Ctf7vwAAAAAAABVA4XoUrkfh4j\u002f2KFyPwvUOQLgehetRuJ6\u002f4XoUrkfh6j8 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="f36e1b83-85b9-425b-b84a-00d38141cea2" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f36e1b83-85b9-425b-b84a-00d38141cea2")) {                    Plotly.newPlot(                        "f36e1b83-85b9-425b-b84a-00d38141cea2",                        [{"hovertemplate":"RMW=%{x:.4f}\u003cbr\u003emarket=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"exSuR+F65D+amZmZmZnZP\u002fYoXI\u002fC9ei\u002fUrgehetRBkCF61G4HoXbv7gehetRuL4\u002f4XoUrkfhyj8pXI\u002fC9Si8Pz0K16NwPQDAH4XrUbge9b8zMzMzMzPDvx+F61G4HtW\u002fMzMzMzMzwz8zMzMzMzPDPwAAAAAAAOC\u002fmpmZmZmZyb+4HoXrUbjmP2ZmZmZmZu4\u002fFK5H4XoU7j+kcD0K16PQP4\u002fC9Shcj9K\u002fj8L1KFyP0j\u002fhehSuR+Hav7gehetRuM4\u002fj8L1KFyP9r89CtejcD0AQDMzMzMzM+u\u002fCtejcD0K8z9I4XoUrkfxv83MzMzMzPS\u002fMzMzMzMzBcB7FK5H4XrEv6RwPQrXo\u002fQ\u002f4XoUrkfh2j89CtejcD36P3sUrkfherQ\u002fUrgehetR2L97FK5H4XrkvwrXo3A9CvO\u002fSOF6FK5HD8CkcD0K16MSQMP1KFyPwsU\u002fH4XrUbgeIkCPwvUoXI\u002f6Pz0K16NwPeo\u002fuB6F61G4CEAK16NwPQrzv+F6FK5H4eq\u002fzczMzMzM3D8zMzMzMzPTPylcj8L1KMw\u002fCtejcD0K7z\u002f2KFyPwvX0P65H4XoUrue\u002fzczMzMzMK8B7FK5H4Xq0vx+F61G4HvE\u002fUrgehetRBkBcj8L1KFzfP\u002fYoXI\u002fC9fi\u002fcT0K16NwCcAfhetRuB7lvwrXo3A9Cv+\u002fw\u002fUoXI\u002fC9b8pXI\u002fC9SjcP4\u002fC9Shcj\u002f6\u002f4XoUrkdhJ0DXo3A9Ctf\u002fP3E9CtejcPW\u002f7FG4HoXr0T\u002fXo3A9CtfrvxSuR+F6FBFAKVyPwvUo+D\u002f2KFyPwvXwP+F6FK5H4QpAexSuR+F6tD9mZmZmZmb2P2ZmZmZmZgRAexSuR+F6CsBI4XoUrkcDwPYoXI\u002fC9fC\u002fKVyPwvUo5L+kcD0K16P0v+xRuB6F68E\u002fMzMzMzMz0789CtejcD3iPwAAAAAAANA\u002f9ihcj8L1\u002fD97FK5H4Xr4P+xRuB6F69E\u002fPQrXo3C9JEB7FK5H4XrkP3sUrkfhevw\u002fXI\u002fC9Shc97\u002fXo3A9Ctf3P0jhehSuR\u002fk\u002fj8L1KFyP4j+F61G4HoXbv1K4HoXrUQRA9ihcj8L1+D9I4XoUrkcDQIXrUbgehdu\u002fCtejcD0K+78K16NwPQr7P0jhehSuR\u002fk\u002fPQrXo3A92r8zMzMzMzMDQHsUrkfhevw\u002fMzMzMzMz8z9SuB6F61EAwGZmZmZmZvo\u002fKVyPwvUovL+uR+F6FK7\u002fv6RwPQrXowRA16NwPQrXIcCPwvUoXI\u002fSv7gehetRuO6\u002fzczMzMzM+L+F61G4HoX\u002fP5qZmZmZmcm\u002fCtejcD0Kt78fhetRuB71v8P1KFyPwgHA16NwPQrX\u002f78pXI\u002fC9SgGwB+F61G4HgfAj8L1KFyPEcCamZmZmZn9vzMzMzMzMwdArkfhehSuBUAK16NwPQoUQAAAAAAAAOA\u002fmpmZmZmZCcCPwvUoXI\u002fSv1K4HoXrURHAj8L1KFyP0r9cj8L1KFwLwFK4HoXrUei\u002fSOF6FK5H4b+4HoXrUbjyPwAAAAAAAPQ\u002fPQrXo3A99j8UrkfhehTyv5qZmZmZmQXAzczMzMzM3D9xPQrXo3DxP4\u002fC9Shcj+I\u002fpHA9Ctej4L8fhetRuB7lvylcj8L1KLy\u002fAAAAAAAA\u002fL9mZmZmZmYEwFK4HoXrUdi\u002fzczMzMzM3D9xPQrXo3ADQHE9CtejcOW\u002fexSuR+F68L+amZmZmZnZv1yPwvUoXO8\u002fUrgehetRyL\u002f2KFyPwvX0vwrXo3A9Cue\u002frkfhehSuAUDhehSuR+HKv3sUrkfhetS\u002frkfhehSu\u002f7+F61G4HoXbPx+F61G4Hu0\u002fAAAAAAAA6D+kcD0K16PwP3E9CtejcO0\u002fCtejcD0Kt7+4HoXrUbiuv8P1KFyPwu0\u002fAAAAAAAAFEAzMzMzMzPTPz0K16NwPeK\u002f9ihcj8L1BkCamZmZmZnJP4\u002fC9Shcj\u002fa\u002fhetRuB6F9z8fhetRuB75PxSuR+F6FOa\u002fw\u002fUoXI\u002fCxT9xPQrXo3DxPxSuR+F6FABAhetRuB6FDcDD9Shcj8Lxv0jhehSuR+E\u002fPQrXo3A98j\u002f2KFyPwvX4v0jhehSuR\u002fm\u002fKVyPwvUo3L8AAAAAAAD4P+F6FK5H4eo\u002fuB6F61G47j+4HoXrUbiev3E9CtejcOW\u002fmpmZmZmZKUBmZmZmZmbuvx+F61G4Hv0\u002fcT0K16NwAcCF61G4HoXbP5qZmZmZmcm\u002fPQrXo3A9EEBmZmZmZmYAQGZmZmZmZv4\u002fUrgehetR\u002fD8K16NwPQoRQFK4HoXrUfS\u002fCtejcD0KC8CkcD0K16PQPylcj8L1KALA7FG4HoXr6T8UrkfhehTeP6RwPQrXo\u002fS\u002fSOF6FK5H8T\u002fXo3A9CtfTv3sUrkfherQ\u002f9ihcj8L1CEDsUbgehevBP+F6FK5H4co\u002fPQrXo3A9EMBmZmZmZmYMwHsUrkfhevS\u002fAAAAAAAA+D+4HoXrUbjuPwrXo3A9Crc\u002fAAAAAAAA8D+amZmZmZn9v0jhehSuRwFAmpmZmZmZyT9SuB6F61HwvwAAAAAAAAAAcT0K16Nw5T8K16NwPQrXv1K4HoXrUci\u002f7FG4HoXrsb\u002f2KFyPwvX8v2ZmZmZmZgRA7FG4HoXrsb+kcD0K16PgP1yPwvUoXPM\u002fPQrXo3A96r\u002fD9Shcj8Llv83MzMzMzPg\u002fj8L1KFwPLkCkcD0K16PwPwrXo3A9Cu+\u0 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ee3880f1-983c-465a-968b-d45f1ee8c5b2" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee3880f1-983c-465a-968b-d45f1ee8c5b2")) {                    Plotly.newPlot(                        "ee3880f1-983c-465a-968b-d45f1ee8c5b2",                        [{"hovertemplate":"HML=%{x:.4f}\u003cbr\u003evolatility=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"7FG4HoXr6b8zMzMzMzP7PwAAAAAAAAAAexSuR+F6pL+uR+F6FK77P+F6FK5H4cq\u002fFK5H4XoU+j97FK5H4XoGQFK4HoXrUQpASOF6FK5H4b\u002f2KFyPwvX8P8P1KFyPwuU\u002fSOF6FK5H6T\u002fsUbgeheuxP4XrUbgehfs\u002fSOF6FK5H8T9SuB6F61EAwHE9CtejcAPACtejcD0K1z8pXI\u002fC9SjMP2ZmZmZmZvI\u002fXI\u002fC9Shc5z\u002fNzMzMzMz4v3E9CtejcM0\u002fhetRuB6FAUBcj8L1KFzvv+xRuB6F68G\u002fzczMzMzM+D97FK5H4XrEPzMzMzMzMwFAKVyPwvUoCkBSuB6F61HYPwrXo3A9CgHACtejcD0K17+amZmZmZn5v1yPwvUoXN8\u002fH4XrUbge7T8AAAAAAADgP7gehetRuN4\u002f7FG4HoXrBUCF61G4HoUSwGZmZmZmZu6\u002fH4XrUbgeIMAUrkfhehQCwBSuR+F6FN4\u002fUrgehetRAsCamZmZmZnpP5qZmZmZmek\u002fAAAAAAAABkDhehSuR+H2P8P1KFyPwgPAUrgehetRCsBcj8L1KFz7v0jhehSuR+G\u002fexSuR+E6MkCuR+F6FK7zPylcj8L1KOS\u002fmpmZmZmZ8b89CtejcD3qPx+F61G4HuU\u002fPQrXo3A9FUCuR+F6FK7vPzMzMzMzM9M\u002fj8L1KFyPBkC4HoXrUbjuv3sUrkfheqQ\u002fFK5H4XoUJMB7FK5H4XrsP+F6FK5H4dq\u002fexSuR+F6lD\u002fXo3A9CtfjP5qZmZmZmfG\u002f4XoUrkfh8j8AAAAAAAAOwMP1KFyPwgnA9ihcj8L1CMAAAAAAAAD0vwrXo3A9CgfAMzMzMzNzNUCF61G4HoUNQFK4HoXrURBAj8L1KFyPGECPwvUoXI8KQClcj8L1KNw\u002fw\u002fUoXI\u002fC7T+PwvUoXI\u002f2P6RwPQrXoxXA4XoUrkfhyj9I4XoUrkf5P6RwPQrXo\u002fA\u002fXI\u002fC9SjcJcDXo3A9Ctfzv5qZmZmZmQ\u002fAhetRuB6F6z9I4XoUrkf1v4XrUbgehf+\u002fexSuR+F6lL8fhetRuB4FQDMzMzMzMwfAUrgehetR4L+4HoXrUbj6v1K4HoXrUdi\u002f9ihcj8L1AECkcD0K16MGwMP1KFyPwvm\u002fuB6F61G4nj\u002fD9Shcj8IFwK5H4XoUrgPAMzMzMzMz4z89CtejcD0SQFyPwvUoXN8\u002fhetRuB6F8z+F61G4HoUTQHE9CtejcAHAAAAAAACAMUA9CtejcD36P4\u002fC9ShcjwRAj8L1KFyPFUBSuB6F61HYPz0K16NwPfI\u002fCtejcD0KFcB7FK5H4XrwP8P1KFyPwgFAj8L1KFyP+j9cj8L1KFwQQArXo3A9ChBAzczMzMxMI0DD9Shcj8IDQOxRuB6F68G\u002fcT0K16Nw7T+kcD0K16MAwI\u002fC9Shcj+o\u002fpHA9CtejFEDhehSuR+EEQLgehetRuBVAUrgehevRI8AAAAAAAADQv7gehetRuL4\u002fhetRuB6FIEDhehSuR+ERwFyPwvUoXANAFK5H4XoU8r8zMzMzMzMQwJqZmZmZmfU\u002fKVyPwvUo\u002fD8fhetRuB7tvx+F61G4HtU\u002fZmZmZmZm1j89CtejcD0AQDMzMzMzM\u002fs\u002fw\u002fUoXI9CIUDXo3A9CtcWQClcj8L1KLy\u002fexSuR+F6xL+kcD0K16P0v1yPwvUoXOc\u002f16NwPQrX+z9I4XoUrkfpP9ejcD0K19O\u002fw\u002fUoXI\u002fCxb97FK5H4Xr4P9ejcD0K1wFAFK5H4XoUHkDNzMzMzMzcP3E9CtejcPE\u002fCtejcD0KC0DsUbgehevpP9ejcD0K1+O\u002fMzMzMzMz478pXI\u002fC9SgGwKRwPQrXo9C\u002f7FG4HoXr+T9xPQrXo3DNP4\u002fC9Shcj9K\u002fpHA9Ctej4D\u002fsUbgehevpP2ZmZmZmZvI\u002fUrgehetRDMCamZmZmZnhvzMzMzMzM+M\u002fAAAAAAAA8L8fhetRuB7lvxSuR+F6FP4\u002fKVyPwvUo9D+kcD0K16MAwB+F61G4HgHA9ihcj8L1AsC4HoXrUbjyP8P1KFyPwuW\u002f7FG4HoXr8T8fhetRuB71P7gehetRuPY\u002fpHA9Ctej\u002fD9I4XoUrkf5vxSuR+F6FO6\u002fSOF6FK5H\u002fb+uR+F6FK4JwArXo3A9CgHA4XoUrkchOMDhehSuR+HiP7gehetRuO6\u002fexSuR+F68D9SuB6F61HYP5qZmZmZmem\u002fKVyPwvUoGcCuR+F6FK4DwHE9CtejcBLAcT0K16NwB8C4HoXrUTggwGZmZmZmZgZA9ihcj8L1GkAK16NwPQrvP4XrUbgeheM\u002fPQrXo3A9AkCF61G4HoXbv4\u002fC9ShcjxRAhetRuB6F47\u002fXo3A9CtcSQHE9CtejcBRAXI\u002fC9ShcEMCPwvUoXI\u002f+P0jhehSuR+k\u002fexSuR+H6KUBcj8L1KFwYQBSuR+F6FA5ApHA9CtejCMB7FK5H4Xr8P\u002fYoXI\u002fC9fg\u002f7FG4HoXrsT9xPQrXo3DxP3E9CtejcM0\u002f9ihcj8L1DMDNzMzMzMz8v7gehetRuK6\u002f7FG4HoVrNEAfhetRuB7lP3sUrkfhegBAhetRuB6F2z9mZmZmZmb2vx+F61G4Hg\u002fAKVyPwvUoFkBcj8L1KFwWQK5H4XoUru8\u002f16NwPQrXE0Bcj8L1KFznvwAAAAAAAPw\u002fCtejcD1KM0BI4XoUrkcLQPYoXI\u002fC9eA\u002fCtejcD0K8z+kcD0K16PQPwAAAAAAAAbA9ihcj8L12D\u002fXo3A9Ctf7vwAAAAAAABVA4XoUrkfh4j\u002f2KFyPwvUOQLgehetRuJ6\u002f4XoUrkf ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="50617b6f-f7ef-4519-b83e-311332265f61" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50617b6f-f7ef-4519-b83e-311332265f61")) {                    Plotly.newPlot(                        "50617b6f-f7ef-4519-b83e-311332265f61",                        [{"hovertemplate":"RMW=%{x:.4f}\u003cbr\u003evolatility=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"exSuR+F65D+amZmZmZnZP\u002fYoXI\u002fC9ei\u002fUrgehetRBkCF61G4HoXbv7gehetRuL4\u002f4XoUrkfhyj8pXI\u002fC9Si8Pz0K16NwPQDAH4XrUbge9b8zMzMzMzPDvx+F61G4HtW\u002fMzMzMzMzwz8zMzMzMzPDPwAAAAAAAOC\u002fmpmZmZmZyb+4HoXrUbjmP2ZmZmZmZu4\u002fFK5H4XoU7j+kcD0K16PQP4\u002fC9Shcj9K\u002fj8L1KFyP0j\u002fhehSuR+Hav7gehetRuM4\u002fj8L1KFyP9r89CtejcD0AQDMzMzMzM+u\u002fCtejcD0K8z9I4XoUrkfxv83MzMzMzPS\u002fMzMzMzMzBcB7FK5H4XrEv6RwPQrXo\u002fQ\u002f4XoUrkfh2j89CtejcD36P3sUrkfherQ\u002fUrgehetR2L97FK5H4XrkvwrXo3A9CvO\u002fSOF6FK5HD8CkcD0K16MSQMP1KFyPwsU\u002fH4XrUbgeIkCPwvUoXI\u002f6Pz0K16NwPeo\u002fuB6F61G4CEAK16NwPQrzv+F6FK5H4eq\u002fzczMzMzM3D8zMzMzMzPTPylcj8L1KMw\u002fCtejcD0K7z\u002f2KFyPwvX0P65H4XoUrue\u002fzczMzMzMK8B7FK5H4Xq0vx+F61G4HvE\u002fUrgehetRBkBcj8L1KFzfP\u002fYoXI\u002fC9fi\u002fcT0K16NwCcAfhetRuB7lvwrXo3A9Cv+\u002fw\u002fUoXI\u002fC9b8pXI\u002fC9SjcP4\u002fC9Shcj\u002f6\u002f4XoUrkdhJ0DXo3A9Ctf\u002fP3E9CtejcPW\u002f7FG4HoXr0T\u002fXo3A9CtfrvxSuR+F6FBFAKVyPwvUo+D\u002f2KFyPwvXwP+F6FK5H4QpAexSuR+F6tD9mZmZmZmb2P2ZmZmZmZgRAexSuR+F6CsBI4XoUrkcDwPYoXI\u002fC9fC\u002fKVyPwvUo5L+kcD0K16P0v+xRuB6F68E\u002fMzMzMzMz0789CtejcD3iPwAAAAAAANA\u002f9ihcj8L1\u002fD97FK5H4Xr4P+xRuB6F69E\u002fPQrXo3C9JEB7FK5H4XrkP3sUrkfhevw\u002fXI\u002fC9Shc97\u002fXo3A9Ctf3P0jhehSuR\u002fk\u002fj8L1KFyP4j+F61G4HoXbv1K4HoXrUQRA9ihcj8L1+D9I4XoUrkcDQIXrUbgehdu\u002fCtejcD0K+78K16NwPQr7P0jhehSuR\u002fk\u002fPQrXo3A92r8zMzMzMzMDQHsUrkfhevw\u002fMzMzMzMz8z9SuB6F61EAwGZmZmZmZvo\u002fKVyPwvUovL+uR+F6FK7\u002fv6RwPQrXowRA16NwPQrXIcCPwvUoXI\u002fSv7gehetRuO6\u002fzczMzMzM+L+F61G4HoX\u002fP5qZmZmZmcm\u002fCtejcD0Kt78fhetRuB71v8P1KFyPwgHA16NwPQrX\u002f78pXI\u002fC9SgGwB+F61G4HgfAj8L1KFyPEcCamZmZmZn9vzMzMzMzMwdArkfhehSuBUAK16NwPQoUQAAAAAAAAOA\u002fmpmZmZmZCcCPwvUoXI\u002fSv1K4HoXrURHAj8L1KFyP0r9cj8L1KFwLwFK4HoXrUei\u002fSOF6FK5H4b+4HoXrUbjyPwAAAAAAAPQ\u002fPQrXo3A99j8UrkfhehTyv5qZmZmZmQXAzczMzMzM3D9xPQrXo3DxP4\u002fC9Shcj+I\u002fpHA9Ctej4L8fhetRuB7lvylcj8L1KLy\u002fAAAAAAAA\u002fL9mZmZmZmYEwFK4HoXrUdi\u002fzczMzMzM3D9xPQrXo3ADQHE9CtejcOW\u002fexSuR+F68L+amZmZmZnZv1yPwvUoXO8\u002fUrgehetRyL\u002f2KFyPwvX0vwrXo3A9Cue\u002frkfhehSuAUDhehSuR+HKv3sUrkfhetS\u002frkfhehSu\u002f7+F61G4HoXbPx+F61G4Hu0\u002fAAAAAAAA6D+kcD0K16PwP3E9CtejcO0\u002fCtejcD0Kt7+4HoXrUbiuv8P1KFyPwu0\u002fAAAAAAAAFEAzMzMzMzPTPz0K16NwPeK\u002f9ihcj8L1BkCamZmZmZnJP4\u002fC9Shcj\u002fa\u002fhetRuB6F9z8fhetRuB75PxSuR+F6FOa\u002fw\u002fUoXI\u002fCxT9xPQrXo3DxPxSuR+F6FABAhetRuB6FDcDD9Shcj8Lxv0jhehSuR+E\u002fPQrXo3A98j\u002f2KFyPwvX4v0jhehSuR\u002fm\u002fKVyPwvUo3L8AAAAAAAD4P+F6FK5H4eo\u002fuB6F61G47j+4HoXrUbiev3E9CtejcOW\u002fmpmZmZmZKUBmZmZmZmbuvx+F61G4Hv0\u002fcT0K16NwAcCF61G4HoXbP5qZmZmZmcm\u002fPQrXo3A9EEBmZmZmZmYAQGZmZmZmZv4\u002fUrgehetR\u002fD8K16NwPQoRQFK4HoXrUfS\u002fCtejcD0KC8CkcD0K16PQPylcj8L1KALA7FG4HoXr6T8UrkfhehTeP6RwPQrXo\u002fS\u002fSOF6FK5H8T\u002fXo3A9CtfTv3sUrkfherQ\u002f9ihcj8L1CEDsUbgehevBP+F6FK5H4co\u002fPQrXo3A9EMBmZmZmZmYMwHsUrkfhevS\u002fAAAAAAAA+D+4HoXrUbjuPwrXo3A9Crc\u002fAAAAAAAA8D+amZmZmZn9v0jhehSuRwFAmpmZmZmZyT9SuB6F61HwvwAAAAAAAAAAcT0K16Nw5T8K16NwPQrXv1K4HoXrUci\u002f7FG4HoXrsb\u002f2KFyPwvX8v2ZmZmZmZgRA7FG4HoXrsb+kcD0K16PgP1yPwvUoXPM\u002fPQrXo3A96r\u002fD9Shcj8Llv83MzMzMzPg\u002fj8L1KFwPLkCkcD0K16PwPwrXo3A9Cu ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="9562434b-5239-483f-a462-bae85c4dd756" class="plotly-graph-div" style="height:500px; width:680px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9562434b-5239-483f-a462-bae85c4dd756")) {                    Plotly.newPlot(                        "9562434b-5239-483f-a462-bae85c4dd756",                        [{"hovertemplate":"CMA=%{x:.4f}\u003cbr\u003evolatility=%{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers","name":"Data","x":{"dtype":"f8","bdata":"ZmZmZmZm8r9SuB6F61HYvzMzMzMzM8M\u002fAAAAAAAAAsApXI\u002fC9SgCQAAAAAAAANC\u002frkfhehSu9z\u002fsUbgehevpP9ejcD0K1wdAFK5H4XoU8r+kcD0K16PAP5qZmZmZmbk\u002fmpmZmZmZ\u002fT\u002fXo3A9CtfTP+xRuB6F6+E\u002fpHA9Ctej4D97FK5H4XrEv83MzMzMzPi\u002fexSuR+F6lL\u002fXo3A9Ctfjv83MzMzMzOQ\u002fKVyPwvUoAsDhehSuR+HiP4XrUbgehds\u002fexSuR+F6tL\u002fsUbgehevpv1yPwvUoXOc\u002fUrgehetR6L\u002fXo3A9Ctfrv5qZmZmZmeG\u002fpHA9Ctej0L8zMzMzMzP3v5qZmZmZmam\u002fcT0K16Nw7b+uR+F6FK73v0jhehSuR+k\u002f16NwPQrX+z+kcD0K16PoP83MzMzMzAJA7FG4HoXrEEAK16NwPQoawHsUrkfhesS\u002frkfhehSuL8DD9Shcj8LtvwAAAAAAAPi\u002fw\u002fUoXI\u002fCDcDsUbgehev5P+xRuB6F6wPASOF6FK5HBUCamZmZmZn1P8P1KFyPwu2\u002f7FG4HoXrBcA9CtejcD0CwLgehetRuJ6\u002fH4XrUbjeMECuR+F6FK4DQGZmZmZmZvK\u002f16NwPQrXDcC4HoXrUbj+v2ZmZmZmZgZAUrgehetRDkAUrkfhehTeP9ejcD0K1+s\u002fuB6F61G4BkAUrkfhehQEwOF6FK5H4f4\u002fH4XrUbgeE8AAAAAAAADoPylcj8L1KNy\u002fexSuR+F6xL\u002fNzMzMzMzwPxSuR+F6FPq\u002fcT0K16Nw\u002fT\u002fXo3A9CtcPwNejcD0K1+O\u002fpHA9CtejAMDhehSuR+HKP7gehetRuP6\u002fpHA9CtfjN0D2KFyPwvUGQK5H4XoUrhFAmpmZmZmZF0BSuB6F61EOQK5H4XoUrgVAhetRuB6F+z\u002fsUbgehevBv+xRuB6F6xfAAAAAAAAAAkA9CtejcD32PzMzMzMzM9M\u002fmpmZmZmZGMCamZmZmZnpvzMzMzMzMwXAMzMzMzMz6z+amZmZmZnJP7gehetRuPq\u002fPQrXo3A99j+4HoXrUbgEQEjhehSuR\u002fm\u002fPQrXo3A99r8pXI\u002fC9Sjcv+F6FK5H4fq\u002fSOF6FK5H4T8AAAAAAADgv5qZmZmZmcm\u002f9ihcj8L18L+F61G4HoX\u002fv2ZmZmZmZta\u002fuB6F61G45r8zMzMzMzMHQIXrUbgehf+\u002fuB6F61G4nj+4HoXrUbgKQB+F61G4HgHAUrgehetRG0CamZmZmZmpPwAAAAAAAOA\u002fKVyPwvUoBEAzMzMzMzP7vwrXo3A9Crc\u002f16NwPQrXCcDXo3A9CtfzP65H4XoUrvs\u002f16NwPQrXBUCPwvUoXI\u002f6P4XrUbgehQNAmpmZmZnZNkBcj8L1KFwFQClcj8L1KNw\u002fH4XrUbgeAUAfhetRuB7Vv9ejcD0K1wdAAAAAAAAAEkC4HoXrUbgEQEjhehSuRxdASOF6FK5HB8AzMzMzMzMHQArXo3A9CgtAzczMzMzM8L\u002fhehSuR+EAwHE9CtejcPW\u002f7FG4HoXr9b\u002fsUbgehevhvx+F61G4HvE\u002f16NwPQrX8z+uR+F6FK7vvz0K16NwPeI\u002fPQrXo3A9AkDXo3A9Ctf7P6RwPQrXo+g\u002fpHA9CtejAkCamZmZmZkNQK5H4XoUru8\u002fzczMzMzM8L89CtejcD32v1K4HoXrUfA\u002fMzMzMzMz0z89CtejcD3ivz0K16NwPfK\u002frkfhehSu17\u002fsUbgeheuxP0jhehSuRwNAmpmZmZmZyb9SuB6F61HIvylcj8L1KLy\u002fpHA9Ctej8D8pXI\u002fC9SjMP1K4HoXrUfS\u002fuB6F61G4vj9xPQrXo3Dlv83MzMzMzOS\u002fcT0K16Nw3b\u002fD9Shcj8LlPx+F61G4HuW\u002fuB6F61G4EEDNzMzMzMzwPwAAAAAAAABAUrgehetR9L+PwvUoXI\u002fSP7gehetRuL6\u002fXI\u002fC9Shc578AAAAAAADgPx+F61G4Hvk\u002fPQrXo3A98j8K16NwPQrzv4XrUbgehfe\u002fMzMzMzMz87+4HoXrUbjuP4\u002fC9Shcj9I\u002fuB6F61G4zj\u002fXo3A9CtfTv+xRuB6F6+G\u002fpHA9Ctej4D9cj8L1KFz3vwAAAAAAAOA\u002f7FG4HoXrwT9I4XoUrkf9vylcj8L1KPC\u002fcT0K16NwJsBcj8L1KFwHQM3MzMzMzPC\u002fw\u002fUoXI\u002fC1T8pXI\u002fC9Sjkv+xRuB6F6+m\u002fhetRuB6FA8Bcj8L1KFznv+F6FK5H4QbA4XoUrkfh9r8UrkfhehQWwFK4HoXrUfQ\u002fFK5H4XoUEUB7FK5H4XoAQOxRuB6F6+G\u002fpHA9Ctej+D97FK5H4Xr8v4XrUbgehQVASOF6FK5HBcAUrkfhehT2Pz0K16NwPQRAUrgehetRBsAAAAAAAADwP5qZmZmZmQNAzczMzMyMMUBI4XoUrkcSQPYoXI\u002fC9QJAmpmZmZmZqb+4HoXrUbi+vz0K16NwPQRACtejcD0K9z\u002fD9Shcj8LFP3sUrkfhepS\u002fMzMzMzMz07+PwvUoXI\u002fSPwAAAAAAAPA\u002fuB6F61F4MEApXI\u002fC9SjwP2ZmZmZmZgZAKVyPwvUo+D\u002fhehSuR+H2v\u002fYoXI\u002fC9ei\u002fCtejcD0KB0CamZmZmZn9PwAAAAAAAOA\u002fAAAAAAAACEB7FK5H4XrkP0jhehSuR\u002fU\u002fpHA9CtejCkApXI\u002fC9Sj4P2ZmZmZmZvI\u002fpHA9Ctej6D9SuB6F61Hgvx+F61G4Hvm\u002fSOF6FK5HAcAfhetRuB7tv ...

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /Users/hippo/Library/Python/3.11/lib/python/site-packages (from plotly) (25.0)
# Downloading plotly-6.3.1-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 12.8 MB/s  0:00:00 eta 0:00:01
# Downloading narwhals-2.10.0-py3-none-any.whl (418 kB)
# Installing collected packages: narwhals, plotly
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]2m1/2 [plotly]
# Successfully installed narwhals-2.10.0 plotly-6.3.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
